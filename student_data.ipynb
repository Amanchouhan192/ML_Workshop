# %%
import pandas as pd

# %%
df = pd.read_excel("C:\\Users\\Aman\\desktop\\student.xlsx")
df
# Out:
#    Roll. No    Name Address         Ph    I_d
# 0         1   rohan   delhi       8489    125
# 1         2   karan  punjab        646     45
# 2         3   arjun    koti     646464    899
# 3         4    nana   bihar    6464646   4df5
# 4         5  harish  madras  645646546  65sdf
# 5         6    ajay     goa     464343   65df
